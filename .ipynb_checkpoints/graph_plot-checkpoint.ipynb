# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def main():
    data = pd.read_csv("stat_data.csv")
    print(data.describe())
    fig,ax = plt.subplots(2,2)
    fig.suptitle("Http rqeuest GET and POST round trip graph")
    ax[0,0].set_title("For 2:1 request ratio")
    ax[0,0].plot(data["client_count"],data["2:1 req"])
    ax[0,1].set_title("For 5:1 request ratio")
    ax[0,1].plot(data["client_count"],data["5:1 req"])
    ax[1,0].set_title("For 10:1 request ratio")
    ax[1,0].plot(data["client_count"],data["10:1 req"])
    

    plt.tight_layout()
    fig.delaxes(ax[1][1])
    plt.show()

# %%
if __name__ == "__main__":
    main()
# Out:
#        client_count        2:1 req        5:1 req       10:1 req
# count      3.000000       3.000000       3.000000       3.000000
# mean      53.333333   54017.333333   54211.333333   54299.333333
# std       45.092498   45242.640908   45488.610248   45415.841887
# min       10.000000   10523.000000   10535.000000   10637.000000
# 25%       30.000000   30613.000000   30658.000000   30806.000000
# 50%       50.000000   50703.000000   50781.000000   50975.000000
# 75%       75.000000   75764.500000   76049.500000   76130.500000
# max      100.000000  100826.000000  101318.000000  101286.000000
